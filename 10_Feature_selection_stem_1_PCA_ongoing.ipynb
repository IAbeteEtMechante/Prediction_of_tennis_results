# %%
import pandas as pd
import numpy as np
import gc
# import warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# ### Reading the datasets

# %%
df = pd.read_csv('data/word2vec/tfidf_stem_1.csv', index_col=0)
df_class = pd.read_csv('data/target.csv', index_col=0)
#add target column
df['Class'] = df_class['Class']

# %% [markdown]
# ##### Do sampling if needed

# %%
#we dont do the sampling, but you might want to change this cell later with some sampling
application  = df.copy()

# %% [markdown]
# ##### Feature matrix and target

# %%
X = df.drop(['Class'], axis=1)
y = application.Class
feature_name = X.columns.tolist()

# %%
X.shape
# Out:
# (50, 1153)

# %% [markdown]
# ### Feature Selection
# - select ___100___ features from ___226___
# - ***xxx_support***: list to represent select this feature or not
# - ***xxx_feature***: the name of selected features

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_sc = scaler.fit_transform(X)

pca = PCA()
X_pca = pca.fit_transform(X_sc)
X_pca.shape
# Out:
# (50, 50)

# %% [markdown]
# #### Let's keep 90% of variance

# %%
explained_variance = pca.explained_variance_ratio_
covered_variance = 0
for i in range(38):
    covered_variance += explained_variance[i]
covered_variance
# Out:
# 0.911763715504207

# %%
pca = PCA(38)
X_pca = pca.fit_transform(X_sc)
X_pca.shape
# Out:
# (50, 38)

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature

# %%
cor_support, cor_feature = cor_selector(X, y)
print(str(len(cor_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# #### 1.2 Chi-2
# ___Note___
# - Normalization: MinMaxScaler (values should be bigger than 0)
# - Impute missing values: yes

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=100)
chi_selector.fit(X_norm, y)
# Out:
# SelectKBest(k=100, score_func=<function chi2 at 0x7fd4ae65a048>)

# %%
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ### 2 Wrapper

# %% [markdown]
# ___Note___
# - Normalization: depend on the used model; yes for LR
# - Impute missing values: depend on the used model; yes for LR

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=5)
rfe_selector.fit(X_norm, y)
# Out:
# Fitting estimator with 1153 features.
# Fitting estimator with 1143 features.
# Fitting estimator with 1133 features.
# Fitting estimator with 1123 features.
# Fitting estimator with 1113 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1093 features.
# Fitting estimator with 1083 features.
# Fitting estimator with 1073 features.
# Fitting estimator with 1063 features.
# Fitting estimator with 1053 features.
# Fitting estimator with 1043 features.
# Fitting estimator with 1033 features.
# Fitting estimator with 1023 features.
# Fitting estimator with 1013 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 993 features.
# Fitting estimator with 983 features.
# Fitting estimator with 973 features.
# Fitting estimator with 963 features.
# Fitting estimator with 953 features.
# Fitting estimator with 943 features.
# Fitting estimator with 933 features.
# Fitting estimator with 923 features.
# Fitting estimator with 913 features.
# Fitting estimator with 903 features.
# Fitting estimator with 893 features.
# Fitting estimator with 883 features.
# Fitting estimator with 873 features.
# Fitting estimator with 863 features.
# Fitting estimator with 853 features.
# Fitting estimator with 843 features.
# Fitting estimator with 833 features.
# Fitting estimator with 823 features.
# Fitting estimator with 813 features.
# Fitting estimator with 803 features.
# Fitting estimator with 793 features.
# Fitting estimator with 783 features.
# Fitting estimator with 773 features.
# Fitting estimator with 763 features.
# Fitting estimator with 753 features.
# Fitting estimator with 743 features.
# Fitting estimator with 733 features.
# Fitting estimator with 723 features.
# Fitting estimator with 713 features.
# Fitting estimator with 703 features.
# Fitting estimator with 693 features.
# Fitting estimator with 683 features.
# Fitting estimator with 673 features.
# Fitting estimator with 663 features.
# Fitting estimator with 653 features.
# Fitting estimator with 643 features.
# Fitting estimator with 633 features.
# Fitting estimator with 623 features.
# Fitting estimator with 613 features.
# Fitting estimator with 603 features.
# Fitting estimator with 593 features.
# Fitting estimator with 583 features.
# Fitting estimator with 573 features.
# Fitting estimator with 563 features.
# Fitting estimator with 553 features.
# Fitting estimator with 543 features.
# Fitting estimator with 533 features.
# Fitting estimator with 523 features.
# Fitting estimator with 513 features.
# Fitting estimator with 503 features.
# Fitting estimator with 493 features.
# Fitting estimator with 483 features.
# Fitting estimator with 473 features.
# Fitting estimator with 463 features.
# Fitting estimator with 453 features.
# Fitting estimator with 443 features.
# Fitting estimator with 433 features.
# Fitting estimator with 423 features.
# Fitting estimator with 413 features.
# Fitting estimator with 403 features.
# Fitting estimator with 393 features.
# Fitting estimator with 383 features.
# Fitting estimator with 373 features.
# Fitting estimator with 363 features.
# Fitting estimator with 353 features.
# Fitting estimator with 343 features.
# Fitting estimator with 333 features.
# Fitting estimator with 323 features.
# Fitting estimator with 313 features.
# Fitting estimator with 303 features.
# Fitting estimator with 293 features.
# Fitting estimator with 283 features.
# Fitting estimator with 273 features.
# Fitting estimator with 263 features.
# Fitting estimator with 253 features.
# Fitting estimator with 243 features.
# Fitting estimator with 233 features.
# Fitting estimator with 223 features.
# Fitting estimator with 213 features.
# Fitting estimator with 203 features.
# Fitting estimator with 193 features.
# Fitting estimator with 183 features.
# Fitting estimator with 173 features.
# Fitting estimator with 163 features.
# Fitting estimator with 153 features.
# Fitting estimator with 143 features.
# Fitting estimator with 133 features.
# Fitting estimator with 123 features.
# Fitting estimator with 113 features.
# Fitting estimator with 103 features.
# RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10,
#     verbose=5)

# %%
rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ### 3. Embeded

# %% [markdown]
# #### 3.1 Logistics Regression L1
# ___Note___
# - Normalization: Yes
# - Impute missing values: Yes

# %%
#change l1 to l2
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l2"), '1.25*median')
embeded_lr_selector.fit(X_norm, y)
# Out:
# /home/user/Documents/Harbour Space/M2_Python_for_Data_Scientists/my_env/lib/python3.6/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass threshold=1.25*median as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# SelectFromModel(estimator=LogisticRegression(), threshold='1.25*median')

# %%
embeded_lr_support = embeded_lr_selector.get_support()
embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
print(str(len(embeded_lr_feature)), 'selected features')
# Out:
# 348 selected features

# %% [markdown]
# #### 3.2 Random Forest
# ___Note___
# - Normalization: No
# - Impute missing values: Yes

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold='1.25*median')
embeded_rf_selector.fit(X, y)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(), threshold='1.25*median')

# %%
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 1153 selected features

# %% [markdown]
# #### 3.3 LightGBM
# ___Note___
# - Normalization: No
# - Impute missing values: No

# %%
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMClassifier

lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
            reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

embeded_lgb_selector = SelectFromModel(lgbc, threshold='1.25*median')
embeded_lgb_selector.fit(X, y)
# Out:
# SelectFromModel(estimator=LGBMClassifier(colsample_bytree=0.2,
#                                          learning_rate=0.05,
#                                          min_child_weight=40,
#                                          min_split_gain=0.01, n_estimators=500,
#                                          num_leaves=32, reg_alpha=3,
#                                          reg_lambda=1),
#                 threshold='1.25*median')

# %%
embeded_lgb_support = embeded_lgb_selector.get_support()
embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
print(str(len(embeded_lgb_feature)), 'selected features')
# Out:
# 1153 selected features

# %% [markdown]
# ### Summary

# %%
pd.set_option('display.max_rows', None)
# put all selection together
feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support, 'Logistics':embeded_lr_support,
                                    'Random Forest':embeded_rf_support, 'LightGBM':embeded_lgb_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df.head(100)
# Out:
#         Feature  Pearson  Chi-2    RFE  Logistics  Random Forest  LightGBM  \
# 1         young     True   True   True       True           True      True
# 2            ye     True   True   True       True           True      True
# 3           won     True   True   True       True           True      True
# 4        whatev     True   True   True       True           True      True
# 5            us     True   True   True       True           True      True
# 6          unit     True   True   True       True           True      True
# 7           two     True   True   True       True           True      True
# 8         twice     True   True   True       True           True      True
# 9         tough     True   True   True       True           True      True
# 10       strong     True   True   True       True           True      True
# 11        stand     True   True   True       True           True      True
# 12        speed     True   True   True       True           True      True
# 13        sofia     True   True   True       True           True      True
# 14        shape     True   True   True       True           True      True
# 15       second     True   True   True       True           True      True
# 16         same     True   True   True       True           True      True
# 17      respect     True   True   True       True           True      True
# 18         real     True   True   True       True           True      True
# 19      qualiti     True   True   True       True           True      True
# 20          put     True   True   True       True           True      True
# 21        pulev     True   True   True       True           True      True
# 22        prove     True   True   True       True           True      True
# 23      pressur     True   True   True       True           True      True
# 24        press     True   True   True       True           True      True
# 25      partner     True   True   True       True           True      True
# 26         over     True   True   True       True           True      True
# 27          out     True   True   True       True           True      True
# 28     otherwis     True   True   True       True           True      True
# 29           or     True   True   True       True           True      True
# 30         noth     True   True   True       True           True      True
# 31         need     True   True   True       True           True      True
# 32        motiv     True   True   True       True           True      True
# 33         mani     True   True   True       True           True      True
# 34          lot     True   True   True       True           True      True
# 35         look     True   True   True       True           True      True
# 36       kubrat     True   True   True       True           True      True
# 37        knock     True   True   True       True           True      True
# 38         keep     True   True   True       True           True      True
# 39         judg     True   True   True       True           True      True
# 40          hit     True   True   True       True           True      True
# 41         here     True   True   True       True           True      True
# 42      healthi     True   True   True       True           True      True
# 43         game     True   True   True       True           True      True
# 44       friend     True   True   True       True           True      True
# 45          fan     True   True   True       True           True      True
# 46         fact     True   True   True       True           True      True
# 47      everyth     True   True   True       True           True      True
# 48          due     True   True   True       True           True      True
# 49        drive     True   True   True       True           True      True
# 50        cours     True   True   True       True           True      True
# 51        coach     True   True   True       True           True      True
# 52         clay     True   True   True       True           True      True
# 53     children     True   True   True       True           True      True
# 54        chain     True   True   True       True           True      True
# 55    bulgarian     True   True   True       True           True      True
# 56        break     True   True   True       True           True      True
# 57         both     True   True   True       True           True      True
# 58          big     True   True   True       True           True      True
# 59      between     True   True   True       True           True      True
# 60       almost     True   True   True       True           True      True
# 61       achiev     True   True   True       True           True      True
# 62        whole     True   True  False       True           True      True
# 63          who     True  False   True       True           True      True
# 64   underestim     True  False   True       True           True      True
# 65          thi     True  False   True       True           True      True
# 66        state     True   True  False       True           True      True
# 67      special     True   True  False       True           True      True
# 68        round    False   True   True       True           True      True
# 69        rival     True   True  False       True           True      True
# 70           re    False   True   True       True           True      True
# 71     particip     True   True  False       True           True      True
# 72        offer     True   True  False       True           True      True
# 73          now     True  False   True       True           True      True
# 74           my     True  False   True       True           True      True
# 75         more     True  False   True       True           True      True
# 76          may     True   True  False       True           True      True
# 77        manag    False   True   True       True           True      True
# 78          man     True   True  False       True           True      True
# 79         loss     True   True  False       True           True      True
# 80        least    False   True   True       True           True      True
# 81        learn    False   True   True       True           True      True
# 82           ha     True  False   True       True           True      True
# 83        guard     True   True  False       True           True      True
# 84          get     True   True  False       True           True      True
# 85      forward     True   True  False       True           True      True
# 86          did     True  False   True       True           True      True
# 87     competit     True   True  False       True           True      True
# 88         club     True   True  False       True           True      True
# 89         case     True   True  False       True           True      True
# 90         cage     True   True  False       True           True      True
# 91      appreci     True   True  False       True           True      True
# 92        after     True   True  False       True           True      True
# 93         year    False  False   True       True           True      True
# 94         work    False  False   True       True           True      True
# 95         want    False  False   True       True           True      True
# 96          use    False  False   True       True           True      True
# 97      unpleas    False   True  False       True           True      True
# 98          top     True  False  False       True           True      True
# 99        today    False  False   True       True           True      True
# 100        time    False  False   True       True           True      True
#
#      Total
# 1        6
# 2        6
# 3        6
# 4        6
# 5        6
# 6        6
# 7        6
# 8        6
# 9        6
# 10       6
# 11       6
# 12       6
# 13       6
# 14       6
# 15       6
# 16       6
# 17       6
# 18       6
# 19       6
# 20       6
# 21       6
# 22       6
# 23       6
# 24       6
# 25       6
# 26       6
# 27       6
# 28       6
# 29       6
# 30       6
# 31       6
# 32       6
# 33       6
# 34       6
# 35       6
# 36       6
# 37       6
# 38       6
# 39       6
# 40       6
# 41       6
# 42       6
# 43       6
# 44       6
# 45       6
# 46       6
# 47       6
# 48       6
# 49       6
# 50       6
# 51       6
# 52       6
# 53       6
# 54       6
# 55       6
# 56       6
# 57       6
# 58       6
# 59       6
# 60       6
# 61       6
# 62       5
# 63       5
# 64       5
# 65       5
# 66       5
# 67       5
# 68       5
# 69       5
# 70       5
# 71       5
# 72       5
# 73       5
# 74       5
# 75       5
# 76       5
# 77       5
# 78       5
# 79       5
# 80       5
# 81       5
# 82       5
# 83       5
# 84       5
# 85       5
# 86       5
# 87       5
# 88       5
# 89       5
# 90       5
# 91       5
# 92       5
# 93       4
# 94       4
# 95       4
# 96       4
# 97       4
# 98       4
# 99       4
# 100      4

# %% [markdown]
# ### Embeded Random Forest Features

# %%
embeded_rf_feature
# Out:
# ['a',
#  'against',
#  'also',
#  'am',
#  'an',
#  'and',
#  'anthoni',
#  'be',
#  'boxer',
#  'but',
#  'camp',
#  'everyth',
#  'excel',
#  'fan',
#  'fought',
#  'give',
#  'good',
#  'had',
#  'happi',
#  'have',
#  'heavyweight',
#  'him',
#  'i',
#  'in',
#  'is',
#  'joshua',
#  'klitschko',
#  'm',
#  'match',
#  'meet',
#  'nice',
#  'now',
#  'of',
#  'one',
#  'opportun',
#  'ring',
#  's',
#  'shape',
#  'show',
#  'strong',
#  'strongest',
#  'than',
#  'that',
#  'the',
#  'thi',
#  'to',
#  'train',
#  'veri',
#  'wa',
#  'want',
#  'weaker',
#  'when',
#  'whi',
#  'will',
#  'with',
#  'world',
#  'wors',
#  'about',
#  'accuraci',
#  'advantag',
#  'battl',
#  'bean',
#  'can',
#  'case',
#  'closer',
#  'do',
#  'everyon',
#  'face',
#  'focus',
#  'for',
#  'game',
#  'get',
#  'go',
#  'gong',
#  'he',
#  'here',
#  'hi',
#  'hope',
#  'import',
#  'improvis',
#  'it',
#  'job',
#  'just',
#  'know',
#  'll',
#  'lot',
#  'mani',
#  'me',
#  'mike',
#  'most',
#  'movement',
#  'much',
#  'my',
#  'not',
#  'nt',
#  'on',
#  'plan',
#  'prepar',
#  're',
#  'readi',
#  'see',
#  'seen',
#  'shock',
#  'so',
#  'some',
#  'speed',
#  'stay',
#  'stick',
#  'strike',
#  'surpris',
#  'take',
#  'talk',
#  'terribl',
#  'them',
#  'thing',
#  'think',
#  'too',
#  'tyson',
#  'underestim',
#  'video',
#  'watch',
#  'we',
#  'weak',
#  'what',
#  'who',
#  'work',
#  'you',
#  'asid',
#  'big',
#  'both',
#  'charact',
#  'compar',
#  'fast',
#  'ha',
#  'heart',
#  'lawrenc',
#  'leav',
#  'light',
#  'lightest',
#  'like',
#  'mean',
#  'neighborhood',
#  'other',
#  'peopl',
#  'play',
#  'punch',
#  'qualiti',
#  'resili',
#  'sharp',
#  'similar',
#  'spar',
#  'strength',
#  'techniqu',
#  'their',
#  'were',
#  'win',
#  'accept',
#  'all',
#  'andi',
#  'at',
#  'bookmak',
#  'break',
#  'caus',
#  'clash',
#  'els',
#  'fact',
#  'make',
#  'matter',
#  'no',
#  'outwit',
#  'problem',
#  'respect',
#  'say',
#  'serious',
#  'team',
#  'there',
#  'up',
#  '29th',
#  'april',
#  'arm',
#  'been',
#  'befor',
#  'broken',
#  'could',
#  'cover',
#  'dark',
#  'dure',
#  'fatigu',
#  'fight',
#  'goal',
#  'gym',
#  'lofti',
#  'more',
#  'never',
#  'out',
#  'place',
#  'push',
#  'rib',
#  'shine',
#  'shoulder',
#  'sometim',
#  'taken',
#  'tri',
#  'under',
#  've',
#  'adrenalin',
#  'ago',
#  'alert',
#  'ali',
#  'anyon',
#  'are',
#  'as',
#  'athlet',
#  'background',
#  'beat',
#  'believ',
#  'belt',
#  'best',
#  'better',
#  'biggest',
#  'box',
#  'bring',
#  'bulgaria',
#  'chanc',
#  'children',
#  'cool',
#  'crazi',
#  'cup',
#  'decid',
#  'depend',
#  'desir',
#  'down',
#  'dream',
#  'equal',
#  'even',
#  'experi',
#  'fear',
#  'feel',
#  'first',
#  'from',
#  'great',
#  'hall',
#  'help',
#  'hobbi',
#  'inspir',
#  'kubrat',
#  'loss',
#  'moham',
#  'motiv',
#  'must',
#  'myself',
#  'need',
#  'normal',
#  'onli',
#  'otherwis',
#  'own',
#  'pancak',
#  'pass',
#  'passion',
#  'person',
#  'point',
#  'popular',
#  'pulev',
#  'put',
#  'quot',
#  'read',
#  'rematch',
#  'reveng',
#  'risk',
#  'romania',
#  'room',
#  'ski',
#  'someth',
#  'special',
#  'street',
#  'strongli',
#  'top',
#  'two',
#  'unit',
#  'use',
#  'walk',
#  'way',
#  'welcom',
#  'well',
#  'where',
#  'winter',
#  'would',
#  'year',
#  'young',
#  'abl',
#  'after',
#  'anyth',
#  'arena',
#  'armeec',
#  'back',
#  'becaus',
#  'club',
#  'effect',
#  'end',
#  'experienc',
#  'fresher',
#  'grigor',
#  'guy',
#  'hit',
#  'holiday',
#  'how',
#  'increas',
#  'intent',
#  'last',
#  'load',
#  'long',
#  'oppon',
#  'or',
#  'paus',
#  'perform',
#  'pleven',
#  'possibl',
#  'press',
#  'scorpio',
#  'seriou',
#  'specif',
#  'sport',
#  'style',
#  'sure',
#  'taught',
#  'threat',
#  'took',
#  'whom',
#  'bottl',
#  'boy',
#  'close',
#  'come',
#  'entourag',
#  'friend',
#  'happen',
#  'head',
#  'kill',
#  'man',
#  'moment',
#  'noth',
#  'plastic',
#  'reason',
#  '27th',
#  'ahead',
#  'audienc',
#  'between',
#  'came',
#  'care',
#  'did',
#  'expect',
#  'father',
#  'forward',
#  'glove',
#  'hundr',
#  'look',
#  'mostli',
#  'octob',
#  'old',
#  'percent',
#  'plovdiv',
#  'quiet',
#  'skill',
#  'sofia',
#  'territori',
#  'upcom',
#  'visit',
#  'week',
#  'which',
#  'again',
#  'around',
#  'beauti',
#  'by',
#  'ca',
#  'chant',
#  'chose',
#  'compet',
#  'danger',
#  'defeat',
#  'enjoy',
#  'favor',
#  'fine',
#  'highest',
#  'level',
#  'met',
#  'month',
#  'next',
#  'posit',
#  'shout',
#  'state',
#  'such',
#  'support',
#  'they',
#  'time',
#  'us',
#  'winner',
#  'won',
#  'accord',
#  'angel',
#  'broke',
#  'bulgarian',
#  'comfort',
#  'exactli',
#  'expos',
#  'faster',
#  'larg',
#  'lo',
#  'love',
#  'necessari',
#  'rememb',
#  'romanian',
#  'rude',
#  'statist',
#  'then',
#  'these',
#  'word',
#  'energi',
#  'screen',
#  'shake',
#  'through',
#  'thumb',
#  'wish',
#  'balanc',
#  'challeng',
#  'charg',
#  'coach',
#  'cope',
#  'definit',
#  'difficult',
#  'front',
#  'furi',
#  'histori',
#  'huey',
#  'interest',
#  'known',
#  'memori',
#  'nativ',
#  'obstacl',
#  'overcom',
#  'part',
#  'remain',
#  'signific',
#  'spectacular',
#  'start',
#  'wait',
#  'weight',
#  'affect',
#  'almost',
#  'alway',
#  'doe',
#  'favorit',
#  'johnson',
#  'kevin',
#  'peter',
#  'round',
#  'samuel',
#  'statu',
#  'still',
#  'tension',
#  'titl',
#  'alexand',
#  'bit',
#  'champion',
#  'chase',
#  'class',
#  'coincid',
#  'demonstr',
#  'hardli',
#  'himself',
#  'howev',
#  'immedi',
#  'knockout',
#  'littl',
#  'question',
#  'saw',
#  'should',
#  'unpleas',
#  'ustinov',
#  'actual',
#  'alreadi',
#  'american',
#  'appear',
#  'arriv',
#  'away',
#  'certainli',
#  'closest',
#  'concentr',
#  'confid',
#  'contend',
#  'contrari',
#  'cours',
#  'day',
#  'declar',
#  'dimitar',
#  'disadvantag',
#  'evid',
#  'extrem',
#  'find',
#  'fresh',
#  'gener',
#  'german',
#  'glad',
#  'guard',
#  'hand',
#  'internet',
#  'offici',
#  'our',
#  'partner',
#  'recent',
#  'regul',
#  'rest',
#  'rival',
#  'russian',
#  'seem',
#  'significantli',
#  'step',
#  'stoimenov',
#  'stop',
#  'thompson',
#  'undoubtedli',
#  'while',
#  'ye',
#  'addit',
#  'ani',
#  'anoth',
#  'ban',
#  'bigger',
#  'brother',
#  'caught',
#  'check',
#  'clean',
#  'clear',
#  'competit',
#  'contract',
#  'control',
#  'correct',
#  'depriv',
#  'dope',
#  'due',
#  'either',
#  'emphas',
#  'escap',
#  'especi',
#  'ever',
#  'excus',
#  'far',
#  'god',
#  'hate',
#  'hide',
#  'honest',
#  'if',
#  'issu',
#  'kid',
#  'machin',
#  'men',
#  'mention',
#  'mine',
#  'name',
#  'olymp',
#  'order',
#  'outsid',
#  'predict',
#  'process',
#  'prove',
#  'reaction',
#  'real',
#  'realli',
#  'right',
#  'rule',
#  'same',
#  'septemb',
#  'sign',
#  'simpl',
#  'someon',
#  'somewhat',
#  'stand',
#  'stimul',
#  'subject',
#  'substanc',
#  'test',
#  'topic',
#  'vitali',
#  'whatev',
#  'worri',
#  'crawl',
#  'kiss',
#  'knock',
#  'leftist',
#  'leg',
#  'over',
#  'pianetta',
#  'complet',
#  'current',
#  'door',
#  'emphasi',
#  'enough',
#  'enter',
#  'fit',
#  'guess',
#  'hard',
#  'opinion',
#  'tomorrow',
#  'trust',
#  'beer',
#  'couch',
#  'minut',
#  'promis',
#  'sit',
#  'truth',
#  '15th',
#  'abov',
#  'accident',
#  'action',
#  'actor',
#  'aint',
#  'al',
#  'allow',
#  'amateur',
#  'analyz',
#  'assur',
#  'attack',
#  'attent',
#  'attract',
#  'avoid',
#  'bad',
#  'becam',
#  'behavior',
#  'below',
#  'bicep',
#  'bitch',
#  'blow',
#  'boat',
#  'border',
#  'brigg',
#  'career',
#  'chizora',
#  'common',
#  'complaint',
#  'confer',
#  'continu',
#  'crap',
#  'cross',
#  'd',
#  'david',
#  'defend',
#  'derek',
#  'deserv',
#  'detail',
#  'develop',
#  'dimitrenko',
#  'direct',
#  'distanc',
#  'doctor',
#  'exampl',
#  'excit',
#  'express',
#  'fate',
#  'fell',
#  'file',
#  'fist',
#  'fli',
#  'form',
#  'formal',
#  'former',
#  'fortun',
#  'four',
#  'frame',
#  'freak',
#  'fritz',
#  'fun',
#  'funni',
#  'further',
#  'gain',
#  'germani',
#  'goe',
#  'got',
#  'guest',
#  'hay',
#  'health',
#  'healthi',
#  'high',
#  'impress',
#  'injuri',
#  'into',
#  'june',
#  'keep',
#  'knew',
#  'latest',
#  'learn',
#  'left',
#  'let',
#  'line',
#  'list',
#  'longer',
#  'lose',
#  'lost',
#  'may',
#  'mayb',
#  'mental',
#  'motorboat',
#  'north',
#  'notic',
#  'novemb',
#  'off',
#  'offer',
#  'often',
#  'overtrain',
#  'past',
#  'patient',
#  'period',
#  'phase',
#  'pictur',
#  'postpon',
#  'pretti',
#  'previou',
#  'pro',
#  'profession',
#  'program',
#  'provoc',
#  'quickli',
#  'quit',
#  'rank',
#  'reach',
#  'recov',
#  'research',
#  'return',
#  'rumor',
#  'said',
#  'selfconfid',
#  'set',
#  'shirt',
#  'short',
#  'shorter',
#  'shot',
#  'slap',
#  'slowli',
#  'sound',
#  'straight',
#  'strategi',
#  'subsid',
#  'success',
#  'tactic',
#  'taller',
#  'tear',
#  'term',
#  'thought',
#  'threw',
#  'tight',
#  'tragedi',
#  'travi',
#  'turn',
#  'understand',
#  'unfortun',
#  'victori',
#  'walker',
#  'water',
#  'went',
#  'whole',
#  'without',
#  'worst',
#  'wrong',
#  'yeah',
#  'your',
#  'zdunek',
#  'abroad',
#  'activ',
#  'art',
#  'aspect',
#  'august',
#  'author',
#  'chain',
#  'circuit',
#  'complex',
#  'countri',
#  'dialogu',
#  'easi',
#  'everi',
#  'few',
#  'flame',
#  'flicker',
#  'foreign',
#  'frequenc',
#  'ground',
#  'martial',
#  'mix',
#  'persever',
#  'race',
#  'rather',
#  'requir',
#  'share',
#  'simpli',
#  'sprint',
#  'strict',
#  'twice',
#  'women',
#  'achiev',
#  'alistair',
#  'ben',
#  'chang',
#  'climb',
#  'combat',
#  'divis',
#  'downsid',
#  'fighter',
#  'hunt',
#  'importantli',
#  'largest',
#  'legend',
#  'lock',
#  'mark',
#  'octagon',
#  'organ',
#  'overim',
#  'physic',
#  'rottwel',
#  'three',
#  'tip',
#  'triumph',
#  'ufc',
#  'variou',
#  'accid',
#  'although',
#  'collaps',
#  'footbal',
#  'highway',
#  'honor',
#  'nasko',
#  'saturday',
#  'selfesteem',
#  'slightli',
#  'struma',
#  'thank',
#  'tougher',
#  '4time',
#  'accur',
#  'advertis',
#  'anyway',
#  'arrang',
#  'awar',
#  'bed',
#  'begin',
#  'behind',
#  'blame',
#  'borisov',
#  'boss',
#  'broadcast',
#  'busi',
#  'cage',
#  'cheap',
#  'cinema',
#  'circl',
#  'cliché',
#  'coffe',
#  'comment',
#  'commit',
#  'compani',
#  'conscious',
#  'da',
#  'dare',
#  'date',
#  'demolit',
#  'differ',
#  'dipchikov',
#  'drive',
#  'dzhubrilov',
#  'eat',
#  'except',
#  'financi',
#  'follow',
#  'food',
#  'forc',
#  'full',
#  'futur',
#  'georgiev',
#  'given',
#  'glori',
#  'grappl',
#  'grate',
#  'half',
#  'hello',
#  'home',
#  'huge',
#  'imposs',
#  'institut',
#  'ivanov',
#  'least',
#  'length',
#  'limb',
#  'lyuben',
#  'm1',
#  'massag',
#  'massiv',
#  'maxfight',
#  'maximum',
#  'moron',
#  'mr',
#  'nail',
#  'nation',
#  'nikola',
#  'ninov',
#  'obvious',
#  'oppos',
#  'pepi',
#  'potenti',
#  'prefer',
#  'promot',
#  'propos',
#  'protect',
#  'public',
#  'realist',
#  'recoveri',
#  'regard',
#  'reliev',
#  'repres',
#  'russia',
#  'salihov',
#  'san',
#  'scare',
#  'second',
#  'somewher',
#  'sponsor',
#  'stage',
#  'stanc',
#  'stoichkov',
#  'sunday',
#  'televis',
#  'third',
#  'throw',
#  'thug',
#  'tournament',
#  'tseco',
#  'uncomfort',
#  'unnecessari',
#  'until',
#  'ventzi',
#  'weapon',
#  'wo',
#  'workout',
#  'yanko',
#  'advanc',
#  'asa',
#  'assess',
#  'bother',
#  'determin',
#  'host',
#  'ident',
#  'intend',
#  'invinc',
#  'judg',
#  'late',
#  'leagu',
#  'moreov',
#  'option',
#  'paramet',
#  'particip',
#  'soil',
#  'solv',
#  'stroke',
#  'stru',
#  'struggl',
#  'tell',
#  'calm',
#  'declin',
#  'greatest',
#  'individu',
#  'player',
#  'sever',
#  'tenni',
#  'wimbledon',
#  'carolin',
#  'court',
#  'elisaveta',
#  'famili',
#  'fewer',
#  'luck',
#  'natur',
#  'new',
#  'parent',
#  'reunion',
#  'sister',
#  'spend',
#  'whenev',
#  'clay',
#  'each',
#  'move',
#  'pair',
#  'quarterfin',
#  'togeth',
#  'tough',
#  'monday',
#  'pressur',
#  'qualifi',
#  'rooki',
#  'season',
#  'star',
#  'carlo',
#  'dimitrov',
#  'fail',
#  'lucki',
#  'madrid',
#  'mont',
#  ...]

# %% [markdown]
# ### Top Features

# %%
top_1_features_df = feature_selection_df.loc[feature_selection_df['Total']==6]
top_1_features = top_1_features_df['Feature']

# %%
top_2_features_df = feature_selection_df.loc[feature_selection_df['Total']==5]
top_2_features = top_2_features_df['Feature']

# %%
top_1_features
# Out:
# 1         young
# 2            ye
# 3           won
# 4        whatev
# 5            us
# 6          unit
# 7           two
# 8         twice
# 9         tough
# 10       strong
# 11        stand
# 12        speed
# 13        sofia
# 14        shape
# 15       second
# 16         same
# 17      respect
# 18         real
# 19      qualiti
# 20          put
# 21        pulev
# 22        prove
# 23      pressur
# 24        press
# 25      partner
# 26         over
# 27          out
# 28     otherwis
# 29           or
# 30         noth
# 31         need
# 32        motiv
# 33         mani
# 34          lot
# 35         look
# 36       kubrat
# 37        knock
# 38         keep
# 39         judg
# 40          hit
# 41         here
# 42      healthi
# 43         game
# 44       friend
# 45          fan
# 46         fact
# 47      everyth
# 48          due
# 49        drive
# 50        cours
# 51        coach
# 52         clay
# 53     children
# 54        chain
# 55    bulgarian
# 56        break
# 57         both
# 58          big
# 59      between
# 60       almost
# 61       achiev
# Name: Feature, dtype: object

# %%
top_2_features
# Out:
# 62         whole
# 63           who
# 64    underestim
# 65           thi
# 66         state
# 67       special
# 68         round
# 69         rival
# 70            re
# 71      particip
# 72         offer
# 73           now
# 74            my
# 75          more
# 76           may
# 77         manag
# 78           man
# 79          loss
# 80         least
# 81         learn
# 82            ha
# 83         guard
# 84           get
# 85       forward
# 86           did
# 87      competit
# 88          club
# 89          case
# 90          cage
# 91       appreci
# 92         after
# Name: Feature, dtype: object

# %% [markdown]
# ### Filters

# %%
top_1_features = list(top_1_features)

# %%
top_1_features_class = top_1_features + ['Class']

# %%
top_2_features = list(top_2_features)

# %%
top_2_features_class = top_2_features + ['Class']

# %%
top_1_and_2_features = top_1_features + top_2_features

# %%
top_1_and_2_features_class = top_1_and_2_features + ['Class']

# %% [markdown]
# ### New Dataframes

# %%
df_top_1 = df.loc[:, top_1_features_class]
df_top_1_and_2 = df.loc[:, top_1_and_2_features_class]

# %% [markdown]
# ### Saving Dataframes

# %%
# !mkdir -p data/w2v_fs

# %%
file_name = 'data/w2v_fs/df_top_1_stem_1.csv'
df_top_1.to_csv(file_name, sep=',', encoding='utf-8', header=True, index=True)

# %%
file_name = 'data/w2v_fs/df_top_1_and_2_stem_1.csv'
df_top_1_and_2.to_csv(file_name, sep=',', encoding='utf-8', header=True, index=True)
