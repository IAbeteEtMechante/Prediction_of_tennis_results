# %%
import pandas as pd
import numpy as np
import gc
# import warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# ### Reading the datasets

# %%
df = pd.read_csv('data/word2vec/tfidf_stem_2.csv', index_col=0)
df_class = pd.read_csv('data/target.csv', index_col=0)
#add target column
df['Class'] = df_class['Class']

# %% [markdown]
# ##### Do sampling if needed

# %%
#we dont do the sampling, but you might want to change this cell later with some sampling
application  = df.copy()

# %% [markdown]
# ##### Feature matrix and target

# %%
X = df.drop(['Class'], axis=1)
y = application.Class
feature_name = X.columns.tolist()

# %%
X.shape
# Out:
# (50, 1068)

# %% [markdown]
# ### Feature Selection
# - select ___100___ features from ___226___
# - ***xxx_support***: list to represent select this feature or not
# - ***xxx_feature***: the name of selected features

# %% [markdown]
# ### 1 Filter

# %% [markdown]
# #### 1.1 Pearson Correlation
#
# ___Note___
# - Normalization: no
# - Impute missing values: yes

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature

# %%
cor_support, cor_feature = cor_selector(X, y)
print(str(len(cor_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# #### 1.2 Chi-2
# ___Note___
# - Normalization: MinMaxScaler (values should be bigger than 0)
# - Impute missing values: yes

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=100)
chi_selector.fit(X_norm, y)
# Out:
# SelectKBest(k=100, score_func=<function chi2 at 0x7f5f1e75a158>)

# %%
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ### 2 Wrapper

# %% [markdown]
# ___Note___
# - Normalization: depend on the used model; yes for LR
# - Impute missing values: depend on the used model; yes for LR

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=5)
rfe_selector.fit(X_norm, y)
# Out:
# Fitting estimator with 1068 features.
# Fitting estimator with 1058 features.
# Fitting estimator with 1048 features.
# Fitting estimator with 1038 features.
# Fitting estimator with 1028 features.
# Fitting estimator with 1018 features.
# Fitting estimator with 1008 features.
# Fitting estimator with 998 features.
# Fitting estimator with 988 features.
# Fitting estimator with 978 features.
# Fitting estimator with 968 features.
# Fitting estimator with 958 features.
# Fitting estimator with 948 features.
# Fitting estimator with 938 features.
# Fitting estimator with 928 features.
# Fitting estimator with 918 features.
# Fitting estimator with 908 features.
# Fitting estimator with 898 features.
# Fitting estimator with 888 features.
# Fitting estimator with 878 features.
# Fitting estimator with 868 features.
# Fitting estimator with 858 features.
# Fitting estimator with 848 features.
# Fitting estimator with 838 features.
# Fitting estimator with 828 features.
# Fitting estimator with 818 features.
# Fitting estimator with 808 features.
# Fitting estimator with 798 features.
# Fitting estimator with 788 features.
# Fitting estimator with 778 features.
# Fitting estimator with 768 features.
# Fitting estimator with 758 features.
# Fitting estimator with 748 features.
# Fitting estimator with 738 features.
# Fitting estimator with 728 features.
# Fitting estimator with 718 features.
# Fitting estimator with 708 features.
# Fitting estimator with 698 features.
# Fitting estimator with 688 features.
# Fitting estimator with 678 features.
# Fitting estimator with 668 features.
# Fitting estimator with 658 features.
# Fitting estimator with 648 features.
# Fitting estimator with 638 features.
# Fitting estimator with 628 features.
# Fitting estimator with 618 features.
# Fitting estimator with 608 features.
# Fitting estimator with 598 features.
# Fitting estimator with 588 features.
# Fitting estimator with 578 features.
# Fitting estimator with 568 features.
# Fitting estimator with 558 features.
# Fitting estimator with 548 features.
# Fitting estimator with 538 features.
# Fitting estimator with 528 features.
# Fitting estimator with 518 features.
# Fitting estimator with 508 features.
# Fitting estimator with 498 features.
# Fitting estimator with 488 features.
# Fitting estimator with 478 features.
# Fitting estimator with 468 features.
# Fitting estimator with 458 features.
# Fitting estimator with 448 features.
# Fitting estimator with 438 features.
# Fitting estimator with 428 features.
# Fitting estimator with 418 features.
# Fitting estimator with 408 features.
# Fitting estimator with 398 features.
# Fitting estimator with 388 features.
# Fitting estimator with 378 features.
# Fitting estimator with 368 features.
# Fitting estimator with 358 features.
# Fitting estimator with 348 features.
# Fitting estimator with 338 features.
# Fitting estimator with 328 features.
# Fitting estimator with 318 features.
# Fitting estimator with 308 features.
# Fitting estimator with 298 features.
# Fitting estimator with 288 features.
# Fitting estimator with 278 features.
# Fitting estimator with 268 features.
# Fitting estimator with 258 features.
# Fitting estimator with 248 features.
# Fitting estimator with 238 features.
# Fitting estimator with 228 features.
# Fitting estimator with 218 features.
# Fitting estimator with 208 features.
# Fitting estimator with 198 features.
# Fitting estimator with 188 features.
# Fitting estimator with 178 features.
# Fitting estimator with 168 features.
# Fitting estimator with 158 features.
# Fitting estimator with 148 features.
# Fitting estimator with 138 features.
# Fitting estimator with 128 features.
# Fitting estimator with 118 features.
# Fitting estimator with 108 features.
# RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10,
#     verbose=5)

# %%
rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ### 3. Embeded

# %% [markdown]
# #### 3.1 Logistics Regression L1
# ___Note___
# - Normalization: Yes
# - Impute missing values: Yes

# %%
#change l1 to l2
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l2"), '1.25*median')
embeded_lr_selector.fit(X_norm, y)
# Out:
# /home/user/Documents/Harbour Space/M2_Python_for_Data_Scientists/my_env/lib/python3.6/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass threshold=1.25*median as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
# SelectFromModel(estimator=LogisticRegression(), threshold='1.25*median')

# %%
embeded_lr_support = embeded_lr_selector.get_support()
embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
print(str(len(embeded_lr_feature)), 'selected features')
# Out:
# 371 selected features

# %% [markdown]
# #### 3.2 Random Forest
# ___Note___
# - Normalization: No
# - Impute missing values: Yes

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold='1.25*median')
embeded_rf_selector.fit(X, y)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(), threshold='1.25*median')

# %%
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 1068 selected features

# %% [markdown]
# #### 3.3 LightGBM
# ___Note___
# - Normalization: No
# - Impute missing values: No

# %%
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMClassifier

lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
            reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

embeded_lgb_selector = SelectFromModel(lgbc, threshold='1.25*median')
embeded_lgb_selector.fit(X, y)
# Out:
# SelectFromModel(estimator=LGBMClassifier(colsample_bytree=0.2,
#                                          learning_rate=0.05,
#                                          min_child_weight=40,
#                                          min_split_gain=0.01, n_estimators=500,
#                                          num_leaves=32, reg_alpha=3,
#                                          reg_lambda=1),
#                 threshold='1.25*median')

# %%
embeded_lgb_support = embeded_lgb_selector.get_support()
embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
print(str(len(embeded_lgb_feature)), 'selected features')
# Out:
# 1068 selected features

# %% [markdown]
# ### Summary

# %%
pd.set_option('display.max_rows', None)
# put all selection together
feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support, 'Logistics':embeded_lr_support,
                                    'Random Forest':embeded_rf_support, 'LightGBM':embeded_lgb_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df.head(100)
# Out:
#         Feature  Pearson  Chi-2    RFE  Logistics  Random Forest  LightGBM  \
# 1         young     True   True   True       True           True      True
# 2            ye     True   True   True       True           True      True
# 3           won     True   True   True       True           True      True
# 4        whatev     True   True   True       True           True      True
# 5          unit     True   True   True       True           True      True
# 6           two     True   True   True       True           True      True
# 7          twic     True   True   True       True           True      True
# 8        strong     True   True   True       True           True      True
# 9         stand     True   True   True       True           True      True
# 10         spee     True   True   True       True           True      True
# 11         spec     True   True   True       True           True      True
# 12         solv     True   True   True       True           True      True
# 13          sof     True   True   True       True           True      True
# 14         shap     True   True   True       True           True      True
# 15       second     True   True   True       True           True      True
# 16          sam     True   True   True       True           True      True
# 17          riv     True   True   True       True           True      True
# 18      respect     True   True   True       True           True      True
# 19          put     True   True   True       True           True      True
# 20        pulev     True   True   True       True           True      True
# 21         prov     True   True   True       True           True      True
# 22        press     True   True   True       True           True      True
# 23           ov     True   True   True       True           True      True
# 24          out     True   True   True       True           True      True
# 25           or     True   True   True       True           True      True
# 26         noth     True   True   True       True           True      True
# 27          nee     True   True   True       True           True      True
# 28          mot     True   True   True       True           True      True
# 29         many     True   True   True       True           True      True
# 30          lot     True   True   True       True           True      True
# 31         look     True   True   True       True           True      True
# 32        least     True   True   True       True           True      True
# 33         kubr     True   True   True       True           True      True
# 34        knock     True   True   True       True           True      True
# 35         keep     True   True   True       True           True      True
# 36         judg     True   True   True       True           True      True
# 37          hit     True   True   True       True           True      True
# 38          get     True   True   True       True           True      True
# 39          gam     True   True   True       True           True      True
# 40       friend     True   True   True       True           True      True
# 41          fan     True   True   True       True           True      True
# 42         fact     True   True   True       True           True      True
# 43      everyth     True   True   True       True           True      True
# 44          due     True   True   True       True           True      True
# 45         driv     True   True   True       True           True      True
# 46        cours     True   True   True       True           True      True
# 47        coach     True   True   True       True           True      True
# 48         clay     True   True   True       True           True      True
# 49        chain     True   True   True       True           True      True
# 50          cas     True   True   True       True           True      True
# 51         bulg     True   True   True       True           True      True
# 52        break     True   True   True       True           True      True
# 53          big     True   True   True       True           True      True
# 54      between     True   True   True       True           True      True
# 55       almost     True   True   True       True           True      True
# 56          aft     True   True   True       True           True      True
# 57         whol     True   True  False       True           True      True
# 58          who     True  False   True       True           True      True
# 59      unpleas    False   True   True       True           True      True
# 60   underestim     True  False   True       True           True      True
# 61          tri     True   True  False       True           True      True
# 62          top     True  False   True       True           True      True
# 63        thing     True  False   True       True           True      True
# 64          thi     True  False   True       True           True      True
# 65         slow     True   True  False       True           True      True
# 66        round    False   True   True       True           True      True
# 67          rom    False   True   True       True           True      True
# 68           re    False   True   True       True           True      True
# 69      problem     True  False   True       True           True      True
# 70        partn     True   True  False       True           True      True
# 71     particip     True   True  False       True           True      True
# 72       otherw     True   True  False       True           True      True
# 73           op    False   True   True       True           True      True
# 74          now     True  False   True       True           True      True
# 75           my     True  False   True       True           True      True
# 76          mor     True  False   True       True           True      True
# 77          may     True   True  False       True           True      True
# 78         loss     True   True  False       True           True      True
# 79        learn    False   True   True       True           True      True
# 80          ind     True   True  False       True           True      True
# 81       import     True  False   True       True           True      True
# 82       honest     True   True  False       True           True      True
# 83      healthy     True   True  False       True           True      True
# 84          has     True  False   True       True           True      True
# 85        guard     True   True  False       True           True      True
# 86          god     True   True   True      False           True      True
# 87      forward     True   True  False       True           True      True
# 88          fac     True  False   True       True           True      True
# 89          did     True  False   True       True           True      True
# 90          day     True  False   True       True           True      True
# 91     competit     True   True  False       True           True      True
# 92         club     True   True  False       True           True      True
# 93       childr     True   True  False       True           True      True
# 94          cag     True   True  False       True           True      True
# 95         brok    False   True   True       True           True      True
# 96         been     True  False   True       True           True      True
# 97      apprecy     True   True  False       True           True      True
# 98       achiev     True   True  False       True           True      True
# 99         year    False  False   True       True           True      True
# 100        want    False  False   True       True           True      True
#
#      Total
# 1        6
# 2        6
# 3        6
# 4        6
# 5        6
# 6        6
# 7        6
# 8        6
# 9        6
# 10       6
# 11       6
# 12       6
# 13       6
# 14       6
# 15       6
# 16       6
# 17       6
# 18       6
# 19       6
# 20       6
# 21       6
# 22       6
# 23       6
# 24       6
# 25       6
# 26       6
# 27       6
# 28       6
# 29       6
# 30       6
# 31       6
# 32       6
# 33       6
# 34       6
# 35       6
# 36       6
# 37       6
# 38       6
# 39       6
# 40       6
# 41       6
# 42       6
# 43       6
# 44       6
# 45       6
# 46       6
# 47       6
# 48       6
# 49       6
# 50       6
# 51       6
# 52       6
# 53       6
# 54       6
# 55       6
# 56       6
# 57       5
# 58       5
# 59       5
# 60       5
# 61       5
# 62       5
# 63       5
# 64       5
# 65       5
# 66       5
# 67       5
# 68       5
# 69       5
# 70       5
# 71       5
# 72       5
# 73       5
# 74       5
# 75       5
# 76       5
# 77       5
# 78       5
# 79       5
# 80       5
# 81       5
# 82       5
# 83       5
# 84       5
# 85       5
# 86       5
# 87       5
# 88       5
# 89       5
# 90       5
# 91       5
# 92       5
# 93       5
# 94       5
# 95       5
# 96       5
# 97       5
# 98       5
# 99       4
# 100      4

# %% [markdown]
# ### Embeded Random Forest Features

# %%
embeded_rf_feature
# Out:
# ['a',
#  'against',
#  'also',
#  'am',
#  'an',
#  'and',
#  'anthony',
#  'be',
#  'box',
#  'but',
#  'camp',
#  'everyth',
#  'excel',
#  'fan',
#  'fought',
#  'giv',
#  'good',
#  'had',
#  'happy',
#  'hav',
#  'heavyweight',
#  'him',
#  'i',
#  'in',
#  'is',
#  'joshu',
#  'klitschko',
#  'm',
#  'match',
#  'meet',
#  'nic',
#  'now',
#  'of',
#  'on',
#  'opportun',
#  'ring',
#  's',
#  'shap',
#  'show',
#  'strong',
#  'strongest',
#  'than',
#  'that',
#  'the',
#  'thi',
#  'to',
#  'train',
#  'very',
#  'want',
#  'was',
#  'weak',
#  'when',
#  'why',
#  'wil',
#  'with',
#  'world',
#  'wors',
#  'about',
#  'acc',
#  'adv',
#  'battl',
#  'bean',
#  'can',
#  'cas',
#  'clos',
#  'do',
#  'everyon',
#  'fac',
#  'focus',
#  'for',
#  'gam',
#  'get',
#  'going',
#  'gong',
#  'he',
#  'her',
#  'his',
#  'hop',
#  'import',
#  'improv',
#  'it',
#  'job',
#  'just',
#  'know',
#  'll',
#  'lot',
#  'many',
#  'me',
#  'mik',
#  'most',
#  'mov',
#  'much',
#  'my',
#  'not',
#  'nt',
#  'plan',
#  'prep',
#  're',
#  'ready',
#  'see',
#  'seen',
#  'shock',
#  'so',
#  'som',
#  'spee',
#  'stay',
#  'stick',
#  'strikes',
#  'surpr',
#  'tak',
#  'talk',
#  'terr',
#  'them',
#  'thing',
#  'think',
#  'too',
#  'tyson',
#  'underestim',
#  'video',
#  'watch',
#  'we',
#  'what',
#  'who',
#  'work',
#  'you',
#  'asid',
#  'big',
#  'both',
#  'charact',
#  'comp',
#  'fast',
#  'has',
#  'heart',
#  'lawr',
#  'leav',
#  'light',
#  'lightest',
#  'lik',
#  'mean',
#  'neighb',
#  'oth',
#  'peopl',
#  'play',
#  'punch',
#  'qual',
#  'resy',
#  'sharp',
#  'simil',
#  'spar',
#  'strengths',
#  'techn',
#  'their',
#  'wer',
#  'win',
#  'acceiv',
#  'al',
#  'andy',
#  'at',
#  'bookmak',
#  'break',
#  'caus',
#  'clash',
#  'els',
#  'fact',
#  'mak',
#  'mat',
#  'no',
#  'outwit',
#  'problem',
#  'respect',
#  'say',
#  'sery',
#  'team',
#  'ther',
#  'up',
#  '29th',
#  'april',
#  'arm',
#  'been',
#  'bef',
#  'brok',
#  'could',
#  'cov',
#  'dark',
#  'dur',
#  'fatigu',
#  'fight',
#  'goal',
#  'gym',
#  'lofty',
#  'mor',
#  'nev',
#  'out',
#  'plac',
#  'push',
#  'rib',
#  'shin',
#  'should',
#  'sometim',
#  'try',
#  'und',
#  've',
#  'adrenalin',
#  'ago',
#  'alert',
#  'anyon',
#  'ar',
#  'as',
#  'athlet',
#  'background',
#  'beat',
#  'believ',
#  'belt',
#  'best',
#  'bet',
#  'biggest',
#  'bring',
#  'bulgar',
#  'chant',
#  'childr',
#  'cool',
#  'crazy',
#  'cup',
#  'decid',
#  'depend',
#  'desir',
#  'down',
#  'dream',
#  'eq',
#  'ev',
#  'expery',
#  'fear',
#  'feel',
#  'first',
#  'from',
#  'gre',
#  'hal',
#  'help',
#  'hobby',
#  'inspir',
#  'kubr',
#  'loss',
#  'moham',
#  'mot',
#  'must',
#  'myself',
#  'nee',
#  'norm',
#  'otherw',
#  'own',
#  'pancak',
#  'pass',
#  'person',
#  'point',
#  'popul',
#  'pulev',
#  'put',
#  'quot',
#  'read',
#  'rematch',
#  'reveng',
#  'risk',
#  'roman',
#  'room',
#  'ski',
#  'someth',
#  'spec',
#  'street',
#  'strongly',
#  'top',
#  'two',
#  'unit',
#  'us',
#  'walk',
#  'way',
#  'wel',
#  'welcom',
#  'wher',
#  'wint',
#  'would',
#  'year',
#  'young',
#  'abl',
#  'aft',
#  'anyth',
#  'aren',
#  'armeec',
#  'back',
#  'becaus',
#  'club',
#  'effect',
#  'end',
#  'fresh',
#  'grig',
#  'guy',
#  'hit',
#  'holiday',
#  'how',
#  'increas',
#  'int',
#  'last',
#  'load',
#  'long',
#  'oppon',
#  'or',
#  'paus',
#  'perform',
#  'plev',
#  'poss',
#  'press',
#  'scorpio',
#  'sport',
#  'styl',
#  'sur',
#  'taught',
#  'threats',
#  'took',
#  'whom',
#  'bottl',
#  'boy',
#  'com',
#  'ento',
#  'friend',
#  'hap',
#  'head',
#  'kil',
#  'man',
#  'mom',
#  'noth',
#  'plast',
#  'reason',
#  '27th',
#  'ahead',
#  'audy',
#  'between',
#  'cam',
#  'car',
#  'did',
#  'expect',
#  'fath',
#  'forward',
#  'glov',
#  'hundr',
#  'look',
#  'octob',
#  'old',
#  'perc',
#  'plovd',
#  'quiet',
#  'skil',
#  'sof',
#  'territ',
#  'upcom',
#  'visit',
#  'week',
#  'which',
#  'again',
#  'around',
#  'beauty',
#  'by',
#  'ca',
#  'chos',
#  'compet',
#  'dang',
#  'def',
#  'enjoy',
#  'fav',
#  'fin',
#  'go',
#  'highest',
#  'level',
#  'met',
#  'month',
#  'next',
#  'posit',
#  'shout',
#  'stat',
#  'such',
#  'support',
#  'they',
#  'tim',
#  'tri',
#  'won',
#  'accord',
#  'angel',
#  'being',
#  'bulg',
#  'comfort',
#  'exact',
#  'expos',
#  'larg',
#  'los',
#  'lov',
#  'necess',
#  'rememb',
#  'rom',
#  'rud',
#  'then',
#  'thes',
#  'word',
#  'energy',
#  'screens',
#  'shak',
#  'through',
#  'thumb',
#  'wish',
#  'bal',
#  'challeng',
#  'charg',
#  'coach',
#  'cop',
#  'definit',
#  'difficult',
#  'front',
#  'fury',
#  'hist',
#  'huey',
#  'interest',
#  'known',
#  'mem',
#  'nat',
#  'obstac',
#  'overcom',
#  'part',
#  'remain',
#  'sign',
#  'spectacul',
#  'start',
#  'wait',
#  'weight',
#  'affect',
#  'almost',
#  'alway',
#  'doe',
#  'favorit',
#  'johnson',
#  'kevin',
#  'pet',
#  'round',
#  'samuel',
#  'stil',
#  'tend',
#  'titl',
#  'alexand',
#  'bit',
#  'champ',
#  'chas',
#  'class',
#  'coincid',
#  'demonst',
#  'hard',
#  'himself',
#  'howev',
#  'immedy',
#  'knockout',
#  'littl',
#  'quest',
#  'saw',
#  'unpleas',
#  'ustinov',
#  'act',
#  'already',
#  'appear',
#  'away',
#  'certain',
#  'closest',
#  'confid',
#  'cont',
#  'contend',
#  'cours',
#  'day',
#  'decl',
#  'dimit',
#  'disadv',
#  'evid',
#  'extrem',
#  'find',
#  'gen',
#  'germ',
#  'glad',
#  'guard',
#  'hand',
#  'internet',
#  'off',
#  'our',
#  'partn',
#  'rec',
#  'reg',
#  'rest',
#  'riv',
#  'russ',
#  'seem',
#  'step',
#  'stoimenov',
#  'stop',
#  'thompson',
#  'undoubt',
#  'whil',
#  'ye',
#  'addit',
#  'anoth',
#  'any',
#  'ban',
#  'broth',
#  'caught',
#  'check',
#  'cle',
#  'clear',
#  'competit',
#  'contract',
#  'control',
#  'correct',
#  'depr',
#  'dop',
#  'due',
#  'eith',
#  'emphas',
#  'escap',
#  'espec',
#  'excus',
#  'far',
#  'god',
#  'hat',
#  'hid',
#  'honest',
#  'if',
#  'issu',
#  'kid',
#  'machin',
#  'men',
#  'ment',
#  'min',
#  'nam',
#  'olymp',
#  'ord',
#  'outsid',
#  'predict',
#  'process',
#  'prov',
#  'react',
#  'real',
#  'right',
#  'rul',
#  'sam',
#  'septemb',
#  'simpl',
#  'someon',
#  'somewh',
#  'stand',
#  'stim',
#  'subject',
#  'subst',
#  'test',
#  'vital',
#  'whatev',
#  'worry',
#  'crawl',
#  'kiss',
#  'knock',
#  'left',
#  'leg',
#  'ov',
#  'pianett',
#  'complet',
#  'cur',
#  'door',
#  'enough',
#  'ent',
#  'fit',
#  'guess',
#  'opin',
#  'tomorrow',
#  'trust',
#  'beer',
#  'couch',
#  'minut',
#  'prom',
#  'sit',
#  'tru',
#  '15th',
#  'abov',
#  'accid',
#  'aint',
#  'allow',
#  'analys',
#  'ass',
#  'attack',
#  'attract',
#  'avoid',
#  'bad',
#  'becam',
#  'behavy',
#  'below',
#  'bicep',
#  'bitch',
#  'blow',
#  'boat',
#  'bord',
#  'brig',
#  'chizor',
#  'common',
#  'complaint',
#  'conf',
#  'continu',
#  'crap',
#  'cross',
#  'd',
#  'david',
#  'defend',
#  'derek',
#  'deserv',
#  'detail',
#  'develop',
#  'dimitrenko',
#  'direct',
#  'dist',
#  'doct',
#  'exampl',
#  'excit',
#  'express',
#  'fat',
#  'fel',
#  'fil',
#  'fist',
#  'fly',
#  'form',
#  'fortun',
#  'four',
#  'fram',
#  'freak',
#  'fritz',
#  'fun',
#  'funny',
#  'furth',
#  'gain',
#  'germany',
#  'goe',
#  'got',
#  'guest',
#  'hay',
#  'heal',
#  'healthy',
#  'high',
#  'impress',
#  'injury',
#  'into',
#  'jun',
#  'keep',
#  'knew',
#  'latest',
#  'learn',
#  'let',
#  'lin',
#  'list',
#  'lost',
#  'may',
#  'mayb',
#  'motorbo',
#  'nor',
#  'novemb',
#  'oft',
#  'overtrain',
#  'past',
#  'paty',
#  'period',
#  'phas',
#  'pict',
#  'postpon',
#  'pretty',
#  'prevy',
#  'pro',
#  'profess',
#  'program',
#  'provoc',
#  'quick',
#  'quit',
#  'rank',
#  'reach',
#  'recov',
#  'research',
#  'return',
#  'rum',
#  'said',
#  'selfconfid',
#  'set',
#  'shirt',
#  'short',
#  'shot',
#  'slap',
#  'slow',
#  'sound',
#  'straight',
#  'strategies',
#  'subsid',
#  'success',
#  'tact',
#  'tal',
#  'tear',
#  'term',
#  'thought',
#  'threw',
#  'tight',
#  'tragedy',
#  'trav',
#  'turn',
#  'understand',
#  'unfortun',
#  'vict',
#  'vita',
#  'wat',
#  'went',
#  'whol',
#  'without',
#  'worst',
#  'wrong',
#  'yeah',
#  'yo',
#  'zdunek',
#  'abroad',
#  'art',
#  'aspect',
#  'august',
#  'auth',
#  'chain',
#  'circuit',
#  'complex',
#  'country',
#  'dialog',
#  'easy',
#  'every',
#  'few',
#  'flam',
#  'flick',
#  'foreign',
#  'frequ',
#  'ground',
#  'mart',
#  'mix',
#  'persev',
#  'rac',
#  'rath',
#  'requir',
#  'shar',
#  'simply',
#  'sprints',
#  'strategy',
#  'strict',
#  'twic',
#  'wom',
#  'achiev',
#  'alistair',
#  'ben',
#  'chang',
#  'climb',
#  'comb',
#  'divid',
#  'downsid',
#  'hunt',
#  'largest',
#  'legend',
#  'lock',
#  'mark',
#  'octagon',
#  'org',
#  'overim',
#  'phys',
#  'rottwel',
#  'three',
#  'tip',
#  'triumph',
#  'ufc',
#  'vary',
#  'although',
#  'collaps',
#  'footbal',
#  'highway',
#  'hon',
#  'nasko',
#  'saturday',
#  'selfesteem',
#  'slight',
#  'struma',
#  'thank',
#  'tough',
#  '4time',
#  'advert',
#  'anyway',
#  'arrang',
#  'aw',
#  'bed',
#  'begin',
#  'behind',
#  'blam',
#  'borisov',
#  'boss',
#  'broadcast',
#  'busy',
#  'cag',
#  'cheap',
#  'cinem',
#  'circ',
#  'cliché',
#  'coff',
#  'commit',
#  'company',
#  'conscy',
#  'da',
#  'dar',
#  'dat',
#  'demolit',
#  'diff',
#  'dipchikov',
#  'driv',
#  'dzhubrilov',
#  'eat',
#  'exceiv',
#  'follow',
#  'food',
#  'forc',
#  'ful',
#  'fut',
#  'georgiev',
#  'glory',
#  'grappl',
#  'grat',
#  'half',
#  'hello',
#  'hom',
#  'hug',
#  'imposs',
#  'institut',
#  'ivanov',
#  'least',
#  'leng',
#  'limb',
#  'lyub',
#  'm1',
#  'mass',
#  'maxfight',
#  'maxim',
#  'mon',
#  'moron',
#  'mr',
#  'nail',
#  'nikol',
#  'ninov',
#  'obvy',
#  'oppos',
#  'pep',
#  'pot',
#  'pref',
#  'promot',
#  'propos',
#  'protect',
#  'publ',
#  'recovery',
#  'regard',
#  'reliev',
#  'repres',
#  'salihov',
#  'san',
#  'scar',
#  'second',
#  'spons',
#  'stag',
#  'stant',
#  'stoichkov',
#  'strength',
#  'sunday',
#  'televid',
#  'third',
#  'throw',
#  'thug',
#  'tourna',
#  'tseco',
#  'uncomfort',
#  'unnecess',
#  'until',
#  'ventz',
#  'weapon',
#  'wo',
#  'workout',
#  'yanko',
#  'assess',
#  'determin',
#  'host',
#  'id',
#  'intend',
#  'invinc',
#  'judg',
#  'lat',
#  'leagu',
#  'moreov',
#  'opt',
#  'paramet',
#  'particip',
#  'soil',
#  'solv',
#  'stroke',
#  'struggle',
#  'strus',
#  'tel',
#  'calm',
#  'declin',
#  'greatest',
#  'individ',
#  'sev',
#  'ten',
#  'wimbledon',
#  'carolin',
#  'court',
#  'elisavet',
#  'famy',
#  'luck',
#  'new',
#  'par',
#  'reun',
#  'sist',
#  'spend',
#  'whenev',
#  'clay',
#  'each',
#  'pair',
#  'quarterfin',
#  'togeth',
#  'monday',
#  'rooky',
#  'season',
#  'star',
#  'carlo',
#  'dimitrov',
#  'fail',
#  'lucky',
#  'madrid',
#  'mont',
#  'rely',
#  'surfac',
#  'amaz',
#  'bound',
#  'homeland',
#  'inert',
#  'limit',
#  'mad',
#  'mind',
#  'sky',
#  'thos',
#  '28th',
#  '8th',
#  'adjust',
#  'ars',
#  'atmosph',
#  'berbatov',
#  'cho',
#  'choos',
#  'col',
#  'contribut',
#  'coop',
#  'distract',
#  'don',
#  'el',
#  'felt',
#  'forget',
#  'found',
#  'franco',
#  'gael',
#  'garro',
#  'hesit',
#  'hotshot',
#  'itself',
#  'lesson',
#  'miss',
#  'regret',
#  'respons',
#  'rocket',
#  'roland',
#  'rush',
#  'scor',
#  'serv',
#  'she',
#  'situ',
#  'subtl',
#  'sud',
#  'told',
#  'emerg',
#  'baghd',
#  'const',
#  'goff',
#  'stabl',
#  'apprecy',
#  'cal',
#  'dud',
#  'fed',
#  'grand',
#  'grass',
#  'ind',
#  'lie',
#  'ont',
#  'physiotherap',
#  'rog',
#  'sel',
#  ...]

# %% [markdown]
# ### Top Features

# %%
top_1_features_df = feature_selection_df.loc[feature_selection_df['Total']==6]
top_1_features = top_1_features_df['Feature']

# %%
top_2_features_df = feature_selection_df.loc[feature_selection_df['Total']==5]
top_2_features = top_2_features_df['Feature']

# %%
top_1_features
# Out:
# 1       young
# 2          ye
# 3         won
# 4      whatev
# 5        unit
# 6         two
# 7        twic
# 8      strong
# 9       stand
# 10       spee
# 11       spec
# 12       solv
# 13        sof
# 14       shap
# 15     second
# 16        sam
# 17        riv
# 18    respect
# 19        put
# 20      pulev
# 21       prov
# 22      press
# 23         ov
# 24        out
# 25         or
# 26       noth
# 27        nee
# 28        mot
# 29       many
# 30        lot
# 31       look
# 32      least
# 33       kubr
# 34      knock
# 35       keep
# 36       judg
# 37        hit
# 38        get
# 39        gam
# 40     friend
# 41        fan
# 42       fact
# 43    everyth
# 44        due
# 45       driv
# 46      cours
# 47      coach
# 48       clay
# 49      chain
# 50        cas
# 51       bulg
# 52      break
# 53        big
# 54    between
# 55     almost
# 56        aft
# Name: Feature, dtype: object

# %%
top_2_features
# Out:
# 57          whol
# 58           who
# 59       unpleas
# 60    underestim
# 61           tri
# 62           top
# 63         thing
# 64           thi
# 65          slow
# 66         round
# 67           rom
# 68            re
# 69       problem
# 70         partn
# 71      particip
# 72        otherw
# 73            op
# 74           now
# 75            my
# 76           mor
# 77           may
# 78          loss
# 79         learn
# 80           ind
# 81        import
# 82        honest
# 83       healthy
# 84           has
# 85         guard
# 86           god
# 87       forward
# 88           fac
# 89           did
# 90           day
# 91      competit
# 92          club
# 93        childr
# 94           cag
# 95          brok
# 96          been
# 97       apprecy
# 98        achiev
# Name: Feature, dtype: object

# %% [markdown]
# ### Filters

# %%
top_1_features = list(top_1_features)

# %%
top_1_features_class = top_1_features + ['Class']

# %%
top_2_features = list(top_2_features)

# %%
top_2_features_class = top_2_features + ['Class']

# %%
top_1_and_2_features = top_1_features + top_2_features

# %%
top_1_and_2_features_class = top_1_and_2_features + ['Class']

# %% [markdown]
# ### New Dataframes

# %%
df_top_1 = df.loc[:, top_1_features_class]
df_top_1_and_2 = df.loc[:, top_1_and_2_features_class]

# %% [markdown]
# ### Saving Dataframes

# %%
# !mkdir -p data/w2v_fs

# %%
file_name = 'data/w2v_fs/df_top_1_stem_2.csv'
df_top_1.to_csv(file_name, sep=',', encoding='utf-8', header=True, index=True)

# %%
file_name = 'data/w2v_fs/df_top_1_and_2_stem_2.csv'
df_top_1_and_2.to_csv(file_name, sep=',', encoding='utf-8', header=True, index=True)
